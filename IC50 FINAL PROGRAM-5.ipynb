# %%
import numpy as np
import numpy
from scipy.optimize import leastsq
import pylab
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import LineString


def normalize(arr, t_min, t_max):
    norm_arr = []
    diff = t_max - t_min
    diff_arr = max(arr) - min(arr)    
    for i in arr:
        temp = (i/max(arr)) * t_max
        norm_arr.append(temp)
    return norm_arr

def GetData(y0):
    
    x = [-2, -1, -0.69897000433, -0.39794000867, -0.096910013, 0.20411998265, 0.50514997832]
    y = normalize(y0, 0, 100)
    if y[6] > y[5]:
        y.pop(6)
        x.pop(6)
        y = normalize(y, 0, 100)
    if y[5] > y[4]:
        y.pop(5)
        x.pop(5)
        y = normalize(y, 0, 100)

    if y[4] > y[3]:
        y.pop(3)
        x.pop(3)

    if y[3] > y[2]:
        y.pop(3)
        x.pop(3)
        y = normalize(y, 0, 100)
    if y[2] > y[1]:
        y.pop(2)
        x.pop(2)
        a = 1
    if y[1] > y[0]:
        y[1] = y[0]


        
    
    if min(y) > 50:
        print("")
        print(">>3.2")
        print("")
        return 
    
    FittingMath(x,y)
    return

def FittingMath(x,y):
	equation = lambda variables,x:	(variables[0]+(variables[1]-variables[0])/(1+10**((variables[2]-x))))
	error = lambda variables,x,y: (equation(variables,x)-y)
	variable_guesses = [numpy.min(y),numpy.max(y),numpy.mean(x)]

	output = leastsq(error,variable_guesses,args=(x,y),full_output=1 )
	variables = output[0]
	fitinfo = output[2]
	r_squared = residuals(y,fitinfo)

	x_range = numpy.arange(numpy.min(x),numpy.max(x),abs(numpy.max(x)/100))

	Grapher(x,y,equation(variables,x_range),x_range,variables[2],r_squared)
	return

def residuals(y,fitinfo):
	fit_error = 0
	fit_variance = 0

	for i in range(len(fitinfo['fvec'])):
		fit_error += (fitinfo['fvec'][i])**2
		fit_variance += (y[i]-numpy.mean(y))**2
	r_squared = 1 - (fit_error/fit_variance)
	return r_squared

def Grapher(x,y,equation,x_range,kd_value,r_squared):

	fig = pylab.figure(1)
	axis = fig.add_subplot(111)
	axis.plot(x,y,'ro',label='data')
	axis.plot(x_range,equation,label='fit')
	axis.set_xlabel('Concentration')
	axis.set_ylabel('Response')
	axis.set_title("Dose Response Fit")
	fig.subplots_adjust(bottom=0.15)
	fig.subplots_adjust(left=0.15)
	rtext = axis.text(0.05, 0.95, 'R^2: %s'% r_squared,transform=axis.transAxes, va='top')
	plt.axhline(y = 50, color = 'r', linestyle = '-')
	pylab.show()

	s= -2
	g = np.interp(s,x,y)
    
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.01
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	if g > 50:
		s+=0.04
		g = np.interp(s,x,y)
	d = 10**s
	print(d, end = '')
	print("    ", end = '')
	print(r_squared)

# %%
df = pd.read_excel("2023.71.xlsx") #CHANGE this to link the correct excell file to the program

dw = pd.DataFrame(df)

mat1 = dw.to_numpy()

a = mat1[154] #association row (this is current set at 75 seconds into association)
d = mat1[264] #dissociation row (this is currently set to 50 seconds into dissociation)
c = mat1[1]

zero = a[1]
zerod = d[1]



print(a[1])


for x in range(0, 8): 
    
    e = 16*x
    ba = a[3 + e] #Baseline Value for Association 2-A20I
    bd = d[3 + e] #Baseline Value for Dissociation 2 - A20I
    ba2 = a[15 + e] #Base Value Max Drug Asso.
    bd2 = a[15 + e] #Base Value Max Drug Diss.

    print("Association 75 sec DRUG # ", end = "")
    print(c[5 + e])
    
    y = [a[1+e], a[5 + e], a[7 + e], a[9 + e], a[11 + e], a[13 + e], a[15 + e]]
    print(y)
    GetData(y)
    print("")
    
    print("Association Rel_DRUG # ", end = "")
    print(c[5 + e])
    if ba < ba2:
        y = [a[1+e] - ba, a[5 + e] - ba, a[7 + e] - ba, a[9 + e] - ba, a[11 + e] - ba, a[13 + e] - ba, a[15 + e] - ba]
        
    elif ba > ba2:
        y = [a[1+e] - ba2, a[5 + e] - ba2, a[7 + e] - ba2, a[9 + e] - ba2, a[11 + e] - ba2, a[13 + e] - ba2, a[15 + e] - ba2]
        
    GetData(y)
    print("")
    
    e = 16*x
    print("Dissociation 130 sec DRUG # ", end = "")
    print(c[5 + e])
    
    y = [d[1+e], d[5 + e], d[7 + e], d[9 + e], d[11 + e], d[13 + e], d[15 + e]]
    print(y)
    GetData(y)
    print("")
    
    print("Dissociation 130 sec Rel_DRUG # ", end = "")
    print(c[5 + e])
    if bd < bd2:
        y = [d[1+e] - bd, d[5 + e] - bd, d[7 + e] - bd, d[9 + e] - bd, d[11 + e] - bd, d[13 + e] - bd, 0]
    elif bd > bd2:
        y = [d[1+e] - bd2, d[5 + e] - bd2, d[7 + e] - bd2, d[9 + e] - bd2, d[11 + e] - bd2, d[13 + e] - bd2, d[15 + e] - bd2]
    GetData(y)
    print("")
# Out:
# 0.23692306
# Association 75 sec DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EDTA
# [0.23692306, 0.27338662, 0.10430791, 0.07424567, 0.0794591, 0.06991952, 0.06709346]
# 0.16982436524617486    0.8521481176821908
#
# Association Rel_DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EDTA
# 0.1445439770745931    0.852148117682166
#
# Dissociation 130 sec DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EDTA
# [0.26199642, 0.26588794, 0.05980483, 0.03407334, 0.03364215, 0.02345945, 0.02129781]
# 0.15848931924611173    0.8175698991804989
#
# Dissociation 130 sec Rel_DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EDTA
# 0.15135612484362118    0.8084906560311409
#
# Association 75 sec DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EGTA
# [0.2372854, 0.25468987, 0.08843646, 0.07850028, 0.06818543, 0.06675838, 0.06967394]
# 0.16982436524617486    0.8064780423506968
#
# Association Rel_DRUG #  Sample ID: hEphB2-His (80 sec) + 0.1 uM EGTA
# 0.1445439770745931    0.8064780423509754
#
# ...
